# %%
#파일 py로 수정
# !jupyter nbconvert --to script final.ipynb
# Out:
# [NbConvertApp] Converting notebook final.ipynb to script
# [NbConvertApp] Writing 22593 bytes to final.py

# %%
# !uvicorn final:app --host 0.0.0.0 --port 7767
# Out:
# INFO:     Started server process [4494]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:7767 (Press CTRL+C to quit)
